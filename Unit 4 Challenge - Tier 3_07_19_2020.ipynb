# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
pd.set_option('display.max_colwidth',1000)
pd.set_option('display.max_rows',1000)
properties.head(5000)
# Out:
#     Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0          NaT      E09000001          E09000002  E09000003  E09000004
# 1   1995-01-01          91449            50460.2    93284.5    64958.1
# 2   1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3   1995-03-01        79120.7              51269    92247.5    64367.5
# 4   1995-04-01        77101.2            53133.5    90762.9    64277.7
# 5   1995-05-01        84409.1            53042.2      90258    63997.1
# 6   1995-06-01        94900.5            53700.3    90107.2    64252.3
# 7   1995-07-01         110128            52113.1    91441.2    63722.7
# 8   1995-08-01         112329            52232.2    92361.3    64432.6
# 9   1995-09-01         104473            51471.6    93273.1    64509.5
# 10  1995-10-01         108038            51513.8    92567.4    64529.9
# 11  1995-11-01         117636            50848.7    90883.2      63846
# ...

# %%
properties.shape
# Out:
# (304, 49)

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_T = properties.T

# %%
properties_T.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_T = properties_T.reset_index()

# %%
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# ...

# %%
properties_T.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            294,     295,     296,     297,     298,     299,     300,     301,
#            302,     303],
#       dtype='object', length=305)

# %%
properties_T.columns = properties_T.iloc[0]

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
properties_T = properties_T.drop(0,)

# %%
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#properties_T.rename(columns = {'Unnamed: 0' : 'London_Borough', np.nan : 'ID'})
properties_T = properties_T.rename(columns = {'Unnamed: 0' : 'London_Borough', pd.NaT : 'ID'})

# %%
properties_T.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %%
properties_T.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2019-06-01 00:00:00, 2019-07-01 00:00:00, 2019-08-01 00:00:00,
#        2019-09-01 00:00:00, 2019-10-01 00:00:00, 2019-11-01 00:00:00,
#        2019-12-01 00:00:00, 2020-01-01 00:00:00, 2020-02-01 00:00:00,
#        2020-03-01 00:00:00],
#       dtype='object', name=0, length=305)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
clean_properties = pd.melt(properties_T, id_vars= ['London_Borough', 'ID'])

# %%
clean_properties.head()
# Out:
#        London_Borough         ID          0    value
# 0      City of London  E09000001 1995-01-01    91449
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2              Barnet  E09000003 1995-01-01  93284.5
# 3              Bexley  E09000004 1995-01-01  64958.1
# 4               Brent  E09000005 1995-01-01  71306.6

# %%
clean_properties = clean_properties.rename(columns={0: 'Month', 'value': 'Average_price'})

# %%
clean_properties.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
clean_properties['Average_price'] = pd.to_numeric(clean_properties['Average_price'])

# %%
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
clean_properties.count()
# Out:
# London_Borough    14544
# ID                13635
# Month             14544
# Average_price     13635
# dtype: int64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
clean_properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
clean_properties[clean_properties['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
clean_properties[clean_properties['Average_price'].isna()]
# Out:
#       London_Borough   ID      Month  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# 94       Unnamed: 47  NaN 1995-02-01            NaN
# 129      Unnamed: 34  NaN 1995-03-01            NaN
# 132      Unnamed: 37  NaN 1995-03-01            NaN
# 142      Unnamed: 47  NaN 1995-03-01            NaN
# 177      Unnamed: 34  NaN 1995-04-01            NaN
# 180      Unnamed: 37  NaN 1995-04-01            NaN
# 190      Unnamed: 47  NaN 1995-04-01            NaN
# 225      Unnamed: 34  NaN 1995-05-01            NaN
# 228      Unnamed: 37  NaN 1995-05-01            NaN
# 238      Unnamed: 47  NaN 1995-05-01            NaN
# 273      Unnamed: 34  NaN 1995-06-01            NaN
# 276      Unnamed: 37  NaN 1995-06-01            NaN
# ...

# %%
NaNFreeDF1 = clean_properties[clean_properties['Average_price'].notna()]
NaNFreeDF1.head(47)
# Out:
#           London_Borough         ID      Month  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %%
NaNFreeDF1.count()
# Out:
# London_Borough    13635
# ID                13635
# Month             13635
# Average_price     13635
# dtype: int64

# %%
NaNFreeDF2 = clean_properties.dropna()
NaNFreeDF2.head(48)
# Out:
#           London_Borough         ID      Month  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %%
NaNFreeDF2.count()
# Out:
# London_Borough    13635
# ID                13635
# Month             13635
# Average_price     13635
# dtype: int64

# %%
NaNFreeDF2['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
print(clean_properties.shape)
print(NaNFreeDF1.shape)
print(NaNFreeDF2.shape)
# Out:
# (14544, 4)
# (13635, 4)
# (13635, 4)

# %%
nonBoroughs = ['Inner London','Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
       'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
       'SOUTH EAST', 'SOUTH WEST', 'England']

# %%
NaNFreeDF2[NaNFreeDF2['London_Borough'].isin(nonBoroughs)]
# Out:
#            London_Borough         ID      Month  Average_price
# 34           Inner London  E13000001 1995-01-01    78251.97650
# 35           Outer London  E13000002 1995-01-01    72958.79836
# 37             NORTH EAST  E12000001 1995-01-01    42076.35411
# 38             NORTH WEST  E12000002 1995-01-01    43958.48001
# 39     YORKS & THE HUMBER  E12000003 1995-01-01    44803.42878
# ...                   ...        ...        ...            ...
# 14538     EAST OF ENGLAND  E12000006 2020-03-01   291253.88780
# 14539              LONDON  E12000007 2020-03-01   485794.08060
# 14540          SOUTH EAST  E12000008 2020-03-01   323353.05240
# 14541          SOUTH WEST  E12000009 2020-03-01   263360.01670
# 14543             England  E92000001 2020-03-01   248271.18770
#
# [3636 rows x 4 columns]

# %%
type(NaNFreeDF2.London_Borough)
# Out:
# pandas.core.series.Series

# %%
NaNFreeDF2[~NaNFreeDF2['London_Borough'].isin(nonBoroughs)]
# Out:
#            London_Borough         ID      Month  Average_price
# 0          City of London  E09000001 1995-01-01   9.144898e+04
# 1      Barking & Dagenham  E09000002 1995-01-01   5.046023e+04
# 2                  Barnet  E09000003 1995-01-01   9.328452e+04
# 3                  Bexley  E09000004 1995-01-01   6.495809e+04
# 4                   Brent  E09000005 1995-01-01   7.130657e+04
# ...                   ...        ...        ...            ...
# 14524              Sutton  E09000029 2020-03-01   3.774585e+05
# 14525       Tower Hamlets  E09000030 2020-03-01   4.726618e+05
# 14526      Waltham Forest  E09000031 2020-03-01   4.371533e+05
# 14527          Wandsworth  E09000032 2020-03-01   6.248581e+05
# 14528         Westminster  E09000033 2020-03-01   1.085013e+06
#
# [9999 rows x 4 columns]

# %%
NaNFreeDF2 = NaNFreeDF2[~NaNFreeDF2['London_Borough'].isin(nonBoroughs)]

# %%
NaNFreeDF2.head()
# Out:
#        London_Borough         ID      Month  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
df = NaNFreeDF2

# %%
df.head()
# Out:
#        London_Borough         ID      Month  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
barnet_prices = df[df['London_Borough'] == 'Barnet']

# %%
barnet_prices.head(5)
# Out:
#     London_Borough         ID      Month  Average_price
# 2           Barnet  E09000003 1995-01-01    93284.51832
# 50          Barnet  E09000003 1995-02-01    93190.16963
# 98          Barnet  E09000003 1995-03-01    92247.52435
# 146         Barnet  E09000003 1995-04-01    90762.87492
# 194         Barnet  E09000003 1995-05-01    90258.00033

# %%
ax = barnet_prices.plot(kind='line', x='Month', y='Average_price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
ax.set_ylabel('Price')
# Out:
# Text(17.200000000000003, 0.5, 'Price')

# %%
barnet_prices.plot(kind='line', x='Month', y='Average_price').set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
df['Year'] = df['Month'].apply(lambda x : x.year)

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df.head(5)
# Out:
#        London_Borough         ID      Month  Average_price  Year
# 0      City of London  E09000001 1995-01-01    91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2              Barnet  E09000003 1995-01-01    93284.51832  1995
# 3              Bexley  E09000004 1995-01-01    64958.09036  1995
# 4               Brent  E09000005 1995-01-01    71306.56698  1995

# %%
pd.set_option('display.max_colwidth',1000)
pd.set_option('display.max_rows',1000)


dfg = df.groupby(by=['London_Borough', 'Year']).mean()
dfg.sample(250)
# Out:
#                            Average_price
# London_Borough       Year
# Bexley               2017   3.356945e+05
# Westminster          2012   6.969260e+05
# Kensington & Chelsea 2014   1.288406e+06
# Hounslow             2018   3.966312e+05
# Haringey             2003   2.203201e+05
# Hillingdon           2007   2.538387e+05
# Brent                2003   2.165018e+05
# Croydon              2003   1.857840e+05
# Kensington & Chelsea 2013   1.126573e+06
# Newham               2007   2.263886e+05
# Haringey             2018   5.515606e+05
# Westminster          1996   1.391888e+05
# Lewisham             2010   2.255823e+05
# Havering             1997   7.621540e+04
# Westminster          2003   3.634660e+05
# Bromley              2011   2.748746e+05
#                      2020   4.339713e+05
# Camden               2012   5.861659e+05
# Hackney              2019   5.556550e+05
# Redbridge            2004   2.229176e+05
# Croydon              2013   2.344399e+05
# ...

# %%
dfg.index
# Out:
# MultiIndex([('Barking & Dagenham', 1995),
#             ('Barking & Dagenham', 1996),
#             ('Barking & Dagenham', 1997),
#             ('Barking & Dagenham', 1998),
#             ('Barking & Dagenham', 1999),
#             ('Barking & Dagenham', 2000),
#             ('Barking & Dagenham', 2001),
#             ('Barking & Dagenham', 2002),
#             ('Barking & Dagenham', 2003),
#             ('Barking & Dagenham', 2004),
#             ...
#             (       'Westminster', 2011),
#             (       'Westminster', 2012),
#             (       'Westminster', 2013),
#             (       'Westminster', 2014),
#             (       'Westminster', 2015),
#             (       'Westminster', 2016),
#             (       'Westminster', 2017),
#             (       'Westminster', 2018),
#             (       'Westminster', 2019),
#             (       'Westminster', 2020)],
#            names=['London_Borough', 'Year'], length=858)

# %%
dfg.reset_index()
# Out:
#            London_Borough  Year  Average_price
# 0      Barking & Dagenham  1995   5.181797e+04
# 1      Barking & Dagenham  1996   5.171819e+04
# 2      Barking & Dagenham  1997   5.597426e+04
# 3      Barking & Dagenham  1998   6.028582e+04
# 4      Barking & Dagenham  1999   6.532093e+04
# 5      Barking & Dagenham  2000   7.754951e+04
# 6      Barking & Dagenham  2001   8.866406e+04
# 7      Barking & Dagenham  2002   1.122219e+05
# 8      Barking & Dagenham  2003   1.424989e+05
# 9      Barking & Dagenham  2004   1.581760e+05
# 10     Barking & Dagenham  2005   1.633608e+05
# 11     Barking & Dagenham  2006   1.678533e+05
# 12     Barking & Dagenham  2007   1.849098e+05
# 13     Barking & Dagenham  2008   1.873569e+05
# 14     Barking & Dagenham  2009   1.564469e+05
# 15     Barking & Dagenham  2010   1.665607e+05
# 16     Barking & Dagenham  2011   1.634651e+05
# 17     Barking & Dagenham  2012   1.658639e+05
# 18     Barking & Dagenham  2013   1.737336e+05
# ...

# %%
dfg = dfg.reset_index()
dfg.head(5)
# Out:
#        London_Borough  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
dfg9 = dfg['Average_price'][dfg['Year']==1998]
dfg9.head(50)
# Out:
# 3       60285.821083
# 29     122359.468033
# 55      80632.020822
# 81     100692.590417
# 107    108286.520467
# 133    170688.973933
# 159    148031.894542
# 185     88143.228830
# 211    111343.154650
# 237     93030.224322
# 263     81532.933366
# 289     87869.535804
# 315    175340.921250
# 341    107419.850108
# 367    114778.250067
# 393     85602.087977
# 419     97676.048952
# 445     99746.069682
# 471    134148.973300
# 497    268350.122142
# 523    116399.769158
# 549    103179.118943
# 575     75539.051649
# 601    108049.855117
# 627     67671.270763
# 653     94514.395822
# 679    162956.066025
# 705     91405.187779
# 731     92087.045921
# 757     96505.166407
# 783     75557.474132
# 809    125406.807233
# 835    190531.949942
# Name: Average_price, dtype: float64

# %%
dfg9.shape
# Out:
# (33,)

# %%
def create_price_ratio(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2018 = float(d['Average_price'][d['Year']==2018])
    ratio = [y1998 / y2018]
    return ratio

# %%
def create_price_difference(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2018 = float(d['Average_price'][d['Year']==2018])
    difference = [y2018 - y1998]
    return difference

# %%
def create_price_percentage_increase(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2018 = float(d['Average_price'][d['Year']==2018])
    percentage_increase = [y2018 / y1998 * 100]
    return percentage_increase

# %%
create_price_ratio(dfg[dfg['London_Borough']=='Barnet'])
# Out:
# [0.22945274120785797]

# %%
final = {}

# %%
final2 = {}

# %%
final3 = {}

# %%
dfg
# Out:
#            London_Borough  Year  Average_price
# 0      Barking & Dagenham  1995   5.181797e+04
# 1      Barking & Dagenham  1996   5.171819e+04
# 2      Barking & Dagenham  1997   5.597426e+04
# 3      Barking & Dagenham  1998   6.028582e+04
# 4      Barking & Dagenham  1999   6.532093e+04
# 5      Barking & Dagenham  2000   7.754951e+04
# 6      Barking & Dagenham  2001   8.866406e+04
# 7      Barking & Dagenham  2002   1.122219e+05
# 8      Barking & Dagenham  2003   1.424989e+05
# 9      Barking & Dagenham  2004   1.581760e+05
# 10     Barking & Dagenham  2005   1.633608e+05
# 11     Barking & Dagenham  2006   1.678533e+05
# 12     Barking & Dagenham  2007   1.849098e+05
# 13     Barking & Dagenham  2008   1.873569e+05
# 14     Barking & Dagenham  2009   1.564469e+05
# 15     Barking & Dagenham  2010   1.665607e+05
# 16     Barking & Dagenham  2011   1.634651e+05
# 17     Barking & Dagenham  2012   1.658639e+05
# 18     Barking & Dagenham  2013   1.737336e+05
# ...

# %%
for b in dfg['London_Borough'].unique():
    final[b] = create_price_ratio(dfg[dfg['London_Borough']==b])
    
print(final)
# Out:
# {'Barking & Dagenham': [0.20422256235393685], 'Barnet': [0.22945274120785797], 'Bexley': [0.2353507654063011], 'Brent': [0.2043086864360114], 'Bromley': [0.24421308489837312], 'Camden': [0.20261973503252542], 'City of London': [0.18862157770244367], 'Croydon': [0.23803288028014047], 'Ealing': [0.23194048191708755], 'Enfield': [0.23455064269011863], 'Greenwich': [0.20995010893854218], 'Hackney': [0.16133493530705734], 'Hammersmith & Fulham': [0.24167443054605853], 'Haringey': [0.19475619095546956], 'Harrow': [0.24635417785626296], 'Havering': [0.23120155787014757], 'Hillingdon': [0.23807975835429931], 'Hounslow': [0.25148317824115635], 'Islington': [0.20643891170300285], 'Kensington & Chelsea': [0.19675491852791563], 'Kingston upon Thames': [0.23416190234282552], 'Lambeth': [0.20170435486140822], 'Lewisham': [0.1835124676472171], 'Merton': [0.21091380604361798], 'Newham': [0.18848754146121072], 'Redbridge': [0.2236545053715767], 'Richmond upon Thames': [0.24967779731157863], 'Southwar
# ...

# %%
for b in dfg['London_Borough'].unique():
    final2[b] = create_price_difference(dfg[dfg['London_Borough']==b])
    
print(final2)
# Out:
# {'Barking & Dagenham': [234910.85252833331], 'Barnet': [410907.06602166675], 'Bexley': [261971.58483250003], 'Brent': [392152.7808358334], 'Bromley': [335123.4651683333], 'Camden': [671721.4354275], 'City of London': [636777.0140933334], 'Croydon': [282155.31449000014], 'Ealing': [368707.3899108334], 'Enfield': [303601.49347999995], 'Greenwich': [306811.39175999997], 'Hackney': [456770.93922333326], 'Hammersmith & Fulham': [550184.4098899999], 'Haringey': [444140.7939016667], 'Harrow': [351129.2131858333], 'Havering': [284646.6627925], 'Hillingdon': [312590.0300583333], 'Hounslow': [296885.110105], 'Islington': [515675.0942333335], 'Kensington & Chelsea': [1095529.9991249999], 'Kingston upon Thames': [380691.2093216667], 'Lambeth': [408357.27804833336], 'Lewisham': [336089.9380191666], 'Merton': [404244.0394533333], 'Newham': [291351.2420141666], 'Redbridge': [328076.6700933333], 'Richmond upon Thames': [489709.36029499996], 'Southwark': [412830.1871658332], 'Sutton': [287175.5346608
# ...

# %%
for b in dfg['London_Borough'].unique():
    final3[b] = create_price_percentage_increase(dfg[dfg['London_Borough']==b])
    
print(final3)
# Out:
# {'Barking & Dagenham': [489.661861291754], 'Barnet': [435.8195917538044], 'Bexley': [424.89770461278766], 'Brent': [489.45544971392866], 'Bromley': [409.4784685333876], 'Camden': [493.53534088842605], 'City of London': [530.1620377587609], 'Croydon': [420.1100280024767], 'Ealing': [431.1450902121834], 'Enfield': [426.347158349581], 'Greenwich': [476.30363473291925], 'Hackney': [619.8285561008662], 'Hammersmith & Fulham': [413.77981019362295], 'Haringey': [513.4624964136042], 'Harrow': [405.91964329643196], 'Havering': [432.52303713353075], 'Hillingdon': [420.02730803844577], 'Hounslow': [397.64091061433294], 'Islington': [484.4048012802298], 'Kensington & Chelsea': [508.2465066092464], 'Kingston upon Thames': [427.0549521484271], 'Lambeth': [495.77511635140627], 'Lewisham': [544.9221041059685], 'Merton': [474.1273313294604], 'Newham': [530.5390437201879], 'Redbridge': [447.1182006097364], 'Richmond upon Thames': [400.5161895721457], 'Southwark': [551.6485302379376], 'Sutton': [411.85
# ...

# %%
df_dif = pd.DataFrame(final2)
df_dif.head()
# Out:
#    Barking & Dagenham         Barnet         Bexley          Brent  \
# 0       234910.852528  410907.066022  261971.584833  392152.780836
#
#          Bromley         Camden  City of London       Croydon         Ealing  \
# 0  335123.465168  671721.435428   636777.014093  282155.31449  368707.389911
#
#         Enfield  ...         Merton         Newham      Redbridge  \
# 0  303601.49348  ...  404244.039453  291351.242014  328076.670093
#
#    Richmond upon Thames      Southwark         Sutton  Tower Hamlets  \
# 0         489709.360295  412830.187166  287175.534661  349995.387378
#
#    Waltham Forest     Wandsworth    Westminster
# 0   365301.936996  471242.331811  829493.303452
#
# [1 rows x 33 columns]

# %%
df_percentage_change = pd.DataFrame(final3)
df_percentage_change.head()
# Out:
#    Barking & Dagenham      Barnet      Bexley      Brent     Bromley  \
# 0          489.661861  435.819592  424.897705  489.45545  409.478469
#
#        Camden  City of London     Croydon     Ealing     Enfield  ...  \
# 0  493.535341      530.162038  420.110028  431.14509  426.347158  ...
#
#        Merton      Newham   Redbridge  Richmond upon Thames  Southwark  \
# 0  474.127331  530.539044  447.118201             400.51619  551.64853
#
#        Sutton  Tower Hamlets  Waltham Forest  Wandsworth  Westminster
# 0  411.852261     462.670104      583.475581  475.770935   535.356539
#
# [1 rows x 33 columns]

# %%
len(final)
# Out:
# 33

# %%
df_ratios = pd.DataFrame(final)

# %%
df_ratios
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley   Camden  \
# 0            0.204223  0.229453  0.235351  0.204309  0.244213  0.20262
#
#    City of London   Croydon   Ealing   Enfield  ...    Merton    Newham  \
# 0        0.188622  0.238033  0.23194  0.234551  ...  0.210914  0.188488
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   0.223655              0.249678   0.181275  0.242806       0.216137
#
#    Waltham Forest  Wandsworth  Westminster
# 0        0.171387    0.210185     0.186791
#
# [1 rows x 33 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
df_dif_T = df_dif.T
df_dif = df_dif_T.reset_index()
df_dif.head()
# Out:
#                 index              0
# 0  Barking & Dagenham  234910.852528
# 1              Barnet  410907.066022
# 2              Bexley  261971.584833
# 3               Brent  392152.780836
# 4             Bromley  335123.465168

# %%
df_percentage_change_T = df_percentage_change.T
df_percentage_change = df_percentage_change_T.reset_index()
df_percentage_change.head()
# Out:
#                 index           0
# 0  Barking & Dagenham  489.661861
# 1              Barnet  435.819592
# 2              Bexley  424.897705
# 3               Brent  489.455450
# 4             Bromley  409.478469

# %%
df_dif.rename(columns={'index':'London_Borough', 0: '2018'}, inplace=True)
df_dif.head()
# Out:
#        London_Borough           2018
# 0  Barking & Dagenham  234910.852528
# 1              Barnet  410907.066022
# 2              Bexley  261971.584833
# 3               Brent  392152.780836
# 4             Bromley  335123.465168

# %%
df_percentage_change.rename(columns={'index':'London_Borough', 0: '2018'}, inplace=True)
df_percentage_change.head()
# Out:
#        London_Borough        2018
# 0  Barking & Dagenham  489.661861
# 1              Barnet  435.819592
# 2              Bexley  424.897705
# 3               Brent  489.455450
# 4             Bromley  409.478469

# %%
#df_ratios = df_ratios.rename(columns={'index':'London Borough', 0: 2018})
df_ratios.rename(columns={'index':'London_Borough', 0: '2018'}, inplace=True)
df_ratios.head()
# Out:
#        London_Borough      2018
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
top15 = df_ratios.sort_values(by='2018', ascending=False).head(15)
print(top15)
# Out:
#           London_Borough      2018
# 17              Hounslow  0.251483
# 26  Richmond upon Thames  0.249678
# 14                Harrow  0.246354
# 4                Bromley  0.244213
# 28                Sutton  0.242806
# 12  Hammersmith & Fulham  0.241674
# 16            Hillingdon  0.238080
# 7                Croydon  0.238033
# 2                 Bexley  0.235351
# 9                Enfield  0.234551
# 20  Kingston upon Thames  0.234162
# 8                 Ealing  0.231940
# 15              Havering  0.231202
# 1                 Barnet  0.229453
# 25             Redbridge  0.223655

# %%
top15_2 = df_dif.sort_values(by='2018', ascending=False).head(15)
print(top15_2)
# Out:
#           London_Borough          2018
# 19  Kensington & Chelsea  1.095530e+06
# 32           Westminster  8.294933e+05
# 5                 Camden  6.717214e+05
# 6         City of London  6.367770e+05
# 12  Hammersmith & Fulham  5.501844e+05
# 18             Islington  5.156751e+05
# 26  Richmond upon Thames  4.897094e+05
# 31            Wandsworth  4.712423e+05
# 11               Hackney  4.567709e+05
# 13              Haringey  4.441408e+05
# 27             Southwark  4.128302e+05
# 1                 Barnet  4.109071e+05
# 21               Lambeth  4.083573e+05
# 23                Merton  4.042440e+05
# 3                  Brent  3.921528e+05

# %%
top33_2 = df_dif.sort_values(by='2018', ascending=False).head(33)
print(top33_2)
# Out:
#           London_Borough          2018
# 19  Kensington & Chelsea  1.095530e+06
# 32           Westminster  8.294933e+05
# 5                 Camden  6.717214e+05
# 6         City of London  6.367770e+05
# 12  Hammersmith & Fulham  5.501844e+05
# 18             Islington  5.156751e+05
# 26  Richmond upon Thames  4.897094e+05
# 31            Wandsworth  4.712423e+05
# 11               Hackney  4.567709e+05
# 13              Haringey  4.441408e+05
# 27             Southwark  4.128302e+05
# 1                 Barnet  4.109071e+05
# 21               Lambeth  4.083573e+05
# 23                Merton  4.042440e+05
# 3                  Brent  3.921528e+05
# 20  Kingston upon Thames  3.806912e+05
# 8                 Ealing  3.687074e+05
# 30        Waltham Forest  3.653019e+05
# 14                Harrow  3.511292e+05
# 29         Tower Hamlets  3.499954e+05
# 22              Lewisham  3.360899e+05
# 4                Bromley  3.351235e+05
# 25             Redbridge  3.280767e+05
# ...

# %%
top32_2 = top33_2[~(top33_2['London_Borough']=='City of London')]

# %%
top33_3 = df_percentage_change.sort_values(by='2018', ascending=False).head(33)
print(top33_3)
# Out:
#           London_Borough        2018
# 11               Hackney  619.828556
# 30        Waltham Forest  583.475581
# 27             Southwark  551.648530
# 22              Lewisham  544.922104
# 32           Westminster  535.356539
# 24                Newham  530.539044
# 6         City of London  530.162038
# 13              Haringey  513.462496
# 19  Kensington & Chelsea  508.246507
# 21               Lambeth  495.775116
# 5                 Camden  493.535341
# 0     Barking & Dagenham  489.661861
# 3                  Brent  489.455450
# 18             Islington  484.404801
# 10             Greenwich  476.303635
# 31            Wandsworth  475.770935
# 23                Merton  474.127331
# 29         Tower Hamlets  462.670104
# 25             Redbridge  447.118201
# 1                 Barnet  435.819592
# 15              Havering  432.523037
# 8                 Ealing  431.145090
# 20  Kingston upon Thames  427.054952
# 9                Enfield  426.347158
# ...

# %%
top32_3 = top33_3[~(top33_3['London_Borough']=='City of London')]

# %%
top15_3 = df_percentage_change.sort_values(by='2018', ascending=False).head(15)
print(top15_3)
# Out:
#           London_Borough        2018
# 11               Hackney  619.828556
# 30        Waltham Forest  583.475581
# 27             Southwark  551.648530
# 22              Lewisham  544.922104
# 32           Westminster  535.356539
# 24                Newham  530.539044
# 6         City of London  530.162038
# 13              Haringey  513.462496
# 19  Kensington & Chelsea  508.246507
# 21               Lambeth  495.775116
# 5                 Camden  493.535341
# 0     Barking & Dagenham  489.661861
# 3                  Brent  489.455450
# 18             Islington  484.404801
# 10             Greenwich  476.303635

# %%
ax = top15[['London_Borough', '2018']].plot(kind='bar')

ax.set_xticklabels(top15.London_Borough)
# Out:
# [Text(0, 0, 'Hounslow'),
#  Text(0, 0, 'Richmond upon Thames'),
#  Text(0, 0, 'Harrow'),
#  Text(0, 0, 'Bromley'),
#  Text(0, 0, 'Sutton'),
#  Text(0, 0, 'Hammersmith & Fulham'),
#  Text(0, 0, 'Hillingdon'),
#  Text(0, 0, 'Croydon'),
#  Text(0, 0, 'Bexley'),
#  Text(0, 0, 'Enfield'),
#  Text(0, 0, 'Kingston upon Thames'),
#  Text(0, 0, 'Ealing'),
#  Text(0, 0, 'Havering'),
#  Text(0, 0, 'Barnet'),
#  Text(0, 0, 'Redbridge')]

# %%
ax = top32_2[['London_Borough', '2018']].plot(kind='bar')

ax.set_xticklabels(top32_2.London_Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Camden'),
#  Text(0, 0, 'Hammersmith & Fulham'),
#  Text(0, 0, 'Islington'),
#  Text(0, 0, 'Richmond upon Thames'),
#  Text(0, 0, 'Wandsworth'),
#  Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'Barnet'),
#  Text(0, 0, 'Lambeth'),
#  Text(0, 0, 'Merton'),
#  Text(0, 0, 'Brent'),
#  Text(0, 0, 'Kingston upon Thames'),
#  Text(0, 0, 'Ealing'),
#  Text(0, 0, 'Waltham Forest'),
#  Text(0, 0, 'Harrow'),
#  Text(0, 0, 'Tower Hamlets'),
#  Text(0, 0, 'Lewisham'),
#  Text(0, 0, 'Bromley'),
#  Text(0, 0, 'Redbridge'),
#  Text(0, 0, 'Hillingdon'),
#  Text(0, 0, 'Greenwich'),
#  Text(0, 0, 'Enfield'),
#  Text(0, 0, 'Hounslow'),
#  Text(0, 0, 'Newham'),
#  Text(0, 0, 'Sutton'),
#  Text(0, 0, 'Havering'),
#  Text(0, 0, 'Croydon'),
#  Text(0, 0, 'Bexley'),
#  Text(0, 0, 'Barking & Dagenham')]

# %%
ax = top32_3[['London_Borough', '2018']].plot(kind='bar')

ax.set_xticklabels(top32_3.London_Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Waltham Forest'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'Lewisham'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Newham'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Lambeth'),
#  Text(0, 0, 'Camden'),
#  Text(0, 0, 'Barking & Dagenham'),
#  Text(0, 0, 'Brent'),
#  Text(0, 0, 'Islington'),
#  Text(0, 0, 'Greenwich'),
#  Text(0, 0, 'Wandsworth'),
#  Text(0, 0, 'Merton'),
#  Text(0, 0, 'Tower Hamlets'),
#  Text(0, 0, 'Redbridge'),
#  Text(0, 0, 'Barnet'),
#  Text(0, 0, 'Havering'),
#  Text(0, 0, 'Ealing'),
#  Text(0, 0, 'Kingston upon Thames'),
#  Text(0, 0, 'Enfield'),
#  Text(0, 0, 'Bexley'),
#  Text(0, 0, 'Croydon'),
#  Text(0, 0, 'Hillingdon'),
#  Text(0, 0, 'Hammersmith & Fulham'),
#  Text(0, 0, 'Sutton'),
#  Text(0, 0, 'Bromley'),
#  Text(0, 0, 'Harrow'),
#  Text(0, 0, 'Richmond upon Thames'),
#  Text(0, 0, 'Hounslow')]

# %%
dfg
# Out:
#            London_Borough  Year  Average_price
# 0      Barking & Dagenham  1995   5.181797e+04
# 1      Barking & Dagenham  1996   5.171819e+04
# 2      Barking & Dagenham  1997   5.597426e+04
# 3      Barking & Dagenham  1998   6.028582e+04
# 4      Barking & Dagenham  1999   6.532093e+04
# 5      Barking & Dagenham  2000   7.754951e+04
# 6      Barking & Dagenham  2001   8.866406e+04
# 7      Barking & Dagenham  2002   1.122219e+05
# 8      Barking & Dagenham  2003   1.424989e+05
# 9      Barking & Dagenham  2004   1.581760e+05
# 10     Barking & Dagenham  2005   1.633608e+05
# 11     Barking & Dagenham  2006   1.678533e+05
# 12     Barking & Dagenham  2007   1.849098e+05
# 13     Barking & Dagenham  2008   1.873569e+05
# 14     Barking & Dagenham  2009   1.564469e+05
# 15     Barking & Dagenham  2010   1.665607e+05
# 16     Barking & Dagenham  2011   1.634651e+05
# 17     Barking & Dagenham  2012   1.658639e+05
# 18     Barking & Dagenham  2013   1.737336e+05
# ...

# %%
dataframe2 = dfg[dfg['Year']==2020]
dataframe2_top15 = dataframe2.sort_values(by='Average_price', ascending=False).head(15)
ax = dataframe2_top15[['London_Borough', 'Average_price']].plot(kind='bar')

ax.set_xticklabels(dataframe2_top15.London_Borough)
# Out:
# [Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Camden'),
#  Text(0, 0, 'City of London'),
#  Text(0, 0, 'Hammersmith & Fulham'),
#  Text(0, 0, 'Islington'),
#  Text(0, 0, 'Richmond upon Thames'),
#  Text(0, 0, 'Wandsworth'),
#  Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Lambeth'),
#  Text(0, 0, 'Barnet'),
#  Text(0, 0, 'Merton'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'Kingston upon Thames')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ### 4. Conclusion answer
#
# What is special about London Borough Hounslow is between 2018 an 1998, i.e. 20 years, its average house price grew the least on a percentage basis.
#
# is the hounslow London Borough having the largest change in average housing price legit?
#
# which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?
#
# Kensington & Chelsea has seen the greatest increase in housing prices on average from 1998 to 2018 at over 1 million dollars.
#
# Looking at percentage growth between 1998 and 2018, the London Borough Hackney had the highest average housing price increase at over 600%.
